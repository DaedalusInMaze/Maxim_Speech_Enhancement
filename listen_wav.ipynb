# %%
import librosa
import IPython.display as ipd

# %%
file = 1

# %%
wav1, fs = librosa.load(f'D:/se/recovered/mixed_speech_{file}.wav', 16000)

# %%
ipd.Audio(wav1,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wav, fs = librosa.load(f'D:/se/recovered/epoch_8_recovered_speech_{file}.wav', 16000)
ipd.Audio(wav,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wav[:20]
# Out:
# array([ 0.00875854,  0.00985718,  0.0055542 ,  0.00637817,  0.01013184,
#         0.02383423,  0.03756714,  0.0579834 ,  0.06643677,  0.06497192,
#         0.04989624,  0.03378296,  0.02038574,  0.01785278,  0.01254272,
#         0.00567627, -0.00784302, -0.0267334 , -0.05682373, -0.09243774],
#       dtype=float32)

# %%
wav1[:20]
# Out:
# array([ 0.00592041,  0.00747681, -0.01248169, -0.0184021 , -0.02944946,
#        -0.03118896, -0.02032471,  0.0017395 ,  0.00762939,  0.00656128,
#         0.01675415, -0.00085449,  0.00091553,  0.00787354,  0.00460815,
#         0.02062988,  0.01644897,  0.02392578, -0.00408936, -0.02914429],
#       dtype=float32)
